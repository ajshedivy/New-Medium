# %%
# %tensorflow_version 1.x
import sys
sys.path.append('/content/drive/My Drive/style_transfer/scripts')
# Out:
# TensorFlow 1.x selected.

# %%
import script_utilities as t

# %%
iterations = [3,5,7]
t.style(iter_list=iterations, input='/content/drive/My Drive/style_transfer/input_images/IMG_2411.JPG',
       style='/content/drive/My Drive/style_transfer/styles/landscape.jpg',
       OUTPUT_PATH='/content/drive/My Drive/style_transfer/style_output',
       INPUT_IMAGE_PATH= '/content/drive/My Drive/style_transfer/input_dump',
       STYLE_IMAGE_PATH='/content/drive/My Drive/style_transfer/style_dump')
# Out:
# input_path:  /content/drive/My Drive/style_transfer/input_dump/input_3.png
# style_path:  /content/drive/My Drive/style_transfer/style_dump/style_3.png
# combined:  /content/drive/My Drive/style_transfer/style_output/combined_3.png
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
iterations = [3]
t.style(iter_list=iterations, input='/content/drive/My Drive/style_transfer/input_images/IMG_2411.JPG',
       style='/content/drive/My Drive/style_transfer/styles/landscape.jpg',
       OUTPUT_PATH='/content/drive/My Drive/style_transfer/style_output',
       INPUT_IMAGE_PATH= '/content/drive/My Drive/style_transfer/input_dump',
       STYLE_IMAGE_PATH='/content/drive/My Drive/style_transfer/style_dump')
# Out:
# input_path:  /content/drive/My Drive/style_transfer/input_dump/input_3.png
# style_path:  /content/drive/My Drive/style_transfer/style_dump/style_3.png
# combined:  /content/drive/My Drive/style_transfer/style_output/combined_3.png
#
# ----------start iterations----------
# Iteration 0 completed with loss 97203879936
# Iteration 1 completed with loss 48751669248
# Iteration 2 completed with loss 34811740160

# %%
# !python '/content/drive/My Drive/style_transfer/scripts/hello.py'
# Out:
# hello there
